# %%
import pandas as pd

data = pd.read_csv('jehle_verb_database.csv')

# fix issue with data

# In the original data, for the specific case where tense is 'Presente' and mood is 'Imperativo Afirmativo',
# the values of 'form_3s' and 'form_2p' were swapped. This code corrects that issue.

# Filter the data for the specific case and create a copy
filtered_data = data[(data['tense'] == 'Presente') & (data['mood'] == 'Imperativo Afirmativo')].copy()

# Swap the values of 'form_3s' and 'form_2p'
filtered_data.loc[:, ['form_3s', 'form_2p']] = filtered_data.loc[:, ['form_2p', 'form_3s']].values

# Update the original data
data.update(filtered_data)

# %%
def conjugation_game(data, verb, tense, mood):
    # Filter the data for the selected verb
    # Get the tense and mood of the verb
    #print(data.head())
    verb_data = data[data['infinitive'] == verb]
   
    verb_data_tense = verb_data[verb_data['tense'] == tense]
    
    #print(verb_data_tense.head())
    #print(mood)
    verb_data_tense_mood = verb_data_tense[verb_data_tense['mood'] == mood]
   
    #print(verb_data_tense_mood.head())

    # List of forms to ask for
    forms = ['form_1s', 'form_2s', 'form_3s', 'form_1p', 'form_2p', 'form_3p']

    # Map form codes to Spanish pronouns
    form_pronouns = {
        'form_1s': 'yo',
        'form_2s': 'tú',
        'form_3s': 'él/ella/usted',
        'form_1p': 'nosotros/nosotras',
        'form_2p': 'vosotros/vosotras',
        'form_3p': 'ellos/ellas/ustedes'
    }
    
    # Start the game
    print("--------------------------------------------------------------------")
    print(f"Let's conjugate the verb '{verb}' in the tense '{tense}' and mood '{mood}'!")

    for form in forms:
        
        # Check if verb_data_tense_mood is empty
        if verb_data_tense_mood.empty:
            print(f"No data found for verb '{verb}' with tense '{tense}' and mood '{mood}'")
            return
        # Get the correct answer
        correct_answer = verb_data_tense_mood[form].values[0]  # Use verb_data_tense_mood instead of data

        # Get the Spanish pronoun for the form
        pronoun = form_pronouns[form]
        
        tries = 0

        while True:
            # count tries
            tries += 1
            
            if tries > 2:
                # give a tip
 
                print(f"Hint: The correct answer is '{correct_answer}'")
                        
            # Ask the user for their answer
            user_answer = input(f"'{pronoun}' ('{verb}') ")
            
            #stop game if user types 'exit'
            if user_answer == 'exit':
                print('Goodbye!')
                return

            if pd.isnull(correct_answer):
                if user_answer.lower() == 'nan':
                    print("Correct!")
                    tries = 0
                    break
            elif user_answer == correct_answer:
                    print("Correct!")
                    tries = 0
                    break
            else:
                print(f"Sorry, that's not correct. Try again.")

# %%
practice_verbs ='''venir
ser
romper
ver
abrir
cubrir
poner
volver
hacer
decir
morir
escribir
'''

verbs = practice_verbs.split('\n')
verbs = [verbs for verbs in verbs if verbs]
print(verbs)
# Out:
# ['venir', 'ser', 'romper', 'ver', 'abrir', 'cubrir', 'poner', 'volver', 'hacer', 'decir', 'morir', 'escribir']

# %%
# Get the list of unique tenses
unique_tenses = data['tense'].unique()

# Get the list of unique moods
unique_moods = data['mood'].unique()

# print in a nice table 

print('Unique tenses:')
print('--------------')
for tense in unique_tenses:
    print(tense)


print('\nUnique moods:')
print('-------------')
for mood in unique_moods:
    print(mood)
# Out:
# Unique tenses:
# --------------
# Presente
# Futuro
# Imperfecto
# Pretérito
# Condicional
# Presente perfecto
# Futuro perfecto
# Pluscuamperfecto
# Pretérito anterior
# Condicional perfecto
#
# Unique moods:
# -------------
# Indicativo
# Subjuntivo
# Imperativo Afirmativo
# Imperativo Negativo

# %%
# Here you choose a tense and a mood to practice
tenses = ['Presente perfecto','Futuro','Condicional']
moods = ['Indicativo']

filtered_data = data[data['infinitive'].isin(verbs)]

# tenses
filtered_data_tenses = filtered_data[filtered_data['tense'].isin(tenses)]
if not filtered_data_tenses.empty:
    filtered_data = filtered_data_tenses

# moods
filtered_data_moods = filtered_data[filtered_data['mood'].isin(moods)]
if not filtered_data_moods.empty:
    filtered_data = filtered_data_moods

filtered_data

# there is a mistake in row 3599 of the database
# Out:
#       infinitive  infinitive_english        mood mood_english  \
# 77         abrir             to open  Indicativo   Indicative
# 3408      cubrir            to cover  Indicativo   Indicative
# 3588       decir        to say, tell  Indicativo   Indicative
# 5388    escribir            to write  Indicativo   Indicative
# 6197       hacer         to do, make  Indicativo   Indicative
# 7619       morir              to die  Indicativo   Indicative
# 8631       poner  to put, place, set  Indicativo   Indicative
# 9906      romper            to break  Indicativo   Indicative
# 10249        ser               to be  Indicativo   Indicative
# 11130      venir             to come  Indicativo   Indicative
# 11148        ver              to see  Indicativo   Indicative
# 11309     volver  to return, go back  Indicativo   Indicative
#
#                    tense    tense_english     verb_english      form_1s  \
# 77     Presente perfecto  Present Perfect    I have opened   he abierto
# 3408   Presente perfecto  Present Perfect   I have covered  he cubierto
# 3588   Presente perfecto  Present Perfect      I have said     he dicho
# 5388   Presente perfecto  Present Perfect   I have written   he escrito
# 6197   Presente perfecto  Present Perfect      I have done     he hecho
# 7619   Presente perfecto  Present Perfect      I have died    he muerto
# 8631   Presente perfecto  Present Perfect       I have put    he puesto
# 9906   Presente perfecto  Present Perfect    I have broken      he roto
# 10249  Presente perfecto  Present Perfect      I have been      he sido
# 11130  Presente perfecto  Present Perfect      I have come    he venido
# 11148  Presente perfecto  Present Perfect      I have seen     he visto
# 11309  Presente perfecto  Present Perfect  I have returned    he vuelto
#
#             form_2s      form_3s         form_1p          form_2p  \
# 77      has abierto   ha abierto   hemos abierto   habéis abierto
# 3408   has cubierto  ha cubierto  hemos cubierto  habéis cubierto
# 3588      has dicho     ha dicho     hemos dicho     habéis dicho
# 5388    has escrito   ha escrito   hemos escrito   habéis escrito
# 6197      has hecho     ha hecho     hemos hecho     habéis hecho
# 7619     has muerto    ha muerto    hemos muerto    habéis muerto
# 8631     has puesto    ha puesto    hemos puesto    habéis puesto
# 9906       has roto      ha roto      hemos roto      habéis roto
# 10249      has sido      ha sido      hemos sido      habéis sido
# 11130    has venido    ha venido    hemos venido    habéis venido
# 11148     has visto     ha visto     hemos visto     habéis visto
# 11309    has vuelto    ha vuelto    hemos vuelto    habéis vuelto
#
#             form_3p       gerund gerund_english pastparticiple  \
# 77      han abierto     abriendo        opening        abierto
# 3408   han cubierto    cubriendo       covering       cubierto
# 3588      han dicho     diciendo         saying          dicho
# 5388    han escrito  escribiendo        writing        escrito
# 6197      han hecho     haciendo          doing          hecho
# 7619     han muerto     muriendo          dying         muerto
# 8631     han puesto     poniendo         puting         puesto
# 9906       han roto    rompiendo       breaking           roto
# 10249      han sido       siendo          being           sido
# 11130    han venido     viniendo         coming         venido
# 11148     han visto       viendo         seeing          visto
# 11309    han vuelto    volviendo      returning         vuelto
#
#       pastparticiple_english
# 77                    opened
# 3408                 covered
# 3588                    said
# 5388                 written
# 6197                    done
# 7619                    died
# 8631                     put
# 9906                  broken
# 10249                   been
# 11130                   come
# 11148                   seen
# 11309               returned

# %%
import random

game_verbs = verbs.copy()
game_ten = tenses.copy()
game_moods = moods.copy()

for i in range(0, len(verbs)*len(tenses)*len(moods)):
    
    condition = True

    while condition:
        random_verb = random.choice(game_verbs)
        random_tense = random.choice(game_ten)
        random_mood = random.choice(game_moods)
        
        if random_mood == 'Subjuntivo':
            if random_tense != 'Presente':
                condition = True
        else:
            condition = False
    
    game_verbs.remove(random_verb)
    
    if len(game_verbs) == 0:
        game_verbs = verbs.copy()

    conjugation_game(filtered_data, random_verb, random_tense, random_mood)
# Out:
# --------------------------------------------------------------------
# Let's conjugate the verb 'ver' in the tense 'Presente perfecto' and mood 'Indicativo'!
# Correct!
# Sorry, that's not correct. Try again.
# Correct!
# Correct!
# Correct!
# Sorry, that's not correct. Try again.
# Sorry, that's not correct. Try again.
# Hint: The correct answer is 'habéis visto'
# Sorry, that's not correct. Try again.
# Hint: The correct answer is 'habéis visto'
# Sorry, that's not correct. Try again.
# Hint: The correct answer is 'habéis visto'
# Goodbye!
# --------------------------------------------------------------------
# Let's conjugate the verb 'decir' in the tense 'Presente perfecto' and mood 'Indicativo'!
# Goodbye!
# --------------------------------------------------------------------
# Let's conjugate the verb 'hacer' in the tense 'Presente perfecto' and mood 'Indicativo'!
# Goodbye!
# --------------------------------------------------------------------
# Let's conjugate the verb 'poner' in the tense 'Presente perfecto' and mood 'Indicativo'!
# Goodbye!
# --------------------------------------------------------------------
# Let's conjugate the verb 'abrir' in the tense 'Presente perfecto' and mood 'Indicativo'!
# Goodbye!
# --------------------------------------------------------------------
# Let's conjugate the verb 'escribir' in the tense 'Presente perfecto' and mood 'Indicativo'!
# Goodbye!
# --------------------------------------------------------------------
# Let's conjugate the verb 'volver' in the tense 'Presente perfecto' and mood 'Indicativo'!
# Goodbye!
# --------------------------------------------------------------------
# Let's conjugate the verb 'morir' in the tense 'Presente perfecto' and mood 'Indicativo'!
# Goodbye!
# --------------------------------------------------------------------
# Let's conjugate the verb 'venir' in the tense 'Presente perfecto' and mood 'Indicativo'!
# Goodbye!
# --------------------------------------------------------------------
# Let's conjugate the verb 'cubrir' in the tense 'Presente perfecto' and mood 'Indicativo'!
# Goodbye!
# --------------------------------------------------------------------
# Let's conjugate the verb 'romper' in the tense 'Presente perfecto' and mood 'Indicativo'!
